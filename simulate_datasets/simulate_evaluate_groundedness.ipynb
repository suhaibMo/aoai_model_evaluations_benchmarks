# %% [markdown]
# # Evaluating Model Groundedness with Azure AI Evaluation SDK
#
# This notebook aims to simulate and evaluate the groundedness of a model endpoint using the Azure AI Evaluation SDK. Groundedness refers to the extent to which the responses generated by a model are based on reliable and verifiable information. Ensuring that a model's outputs are grounded is crucial for maintaining the accuracy and trustworthiness of AI systems.
#
# In this notebook, we will:
#
# 1. Set up the Azure AI Evaluation SDK.
# 2. Define the dataset for evaluating groundedness, which will vary based on the specific use case of your model.
# 3. Simulate the model endpoint and generate responses.
# 4. Evaluate the groundedness of the model's responses using the Azure AI Evaluation SDK.
#
# The dataset used for evaluating groundedness will be tailored to the particular application of your model. For instance, if your model is designed for customer support, the dataset might consist of common customer queries and the corresponding accurate responses. If your model is used for medical diagnosis, the dataset would include medical cases and verified diagnostic information.
#
# By the end of this notebook, you will have a clear understanding of how to assess the groundedness of your model's outputs and ensure that they are based on solid and reliable information.
#
# This tutorial uses the following Azure AI services:
#
# - [azure-ai-evaluation](https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/evaluate-sdk)
#
# ## Time
#
# You should expect to spend 30 minutes running this sample.
#
# ## About this example
#
# This example demonstrates evaluating model endpoints responses against provided prompts using azure-ai-evaluation
#
# ## Before you begin
#
# ### Installation
#
# Install the following packages required to execute this notebook.

# %%
# %pip install azure-ai-evaluation --upgrade
# %pip install promptflow-azure
# %pip install azure-identity
# Out:
# Requirement already satisfied: azure-ai-evaluation in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (1.1.0)
# Requirement already satisfied: azure-core>=1.30.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (1.32.0)
# Requirement already satisfied: promptflow-devkit>=1.15.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (12.24.0)
# Requirement already satisfied: azure-identity>=1.16.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (1.19.0)
# Requirement already satisfied: promptflow-core>=1.15.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: nltk>=3.9.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.12.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.3)
# Requirement already satisfied: cryptography>=2.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (44.0.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: msal>=1.30.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.31.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: tqdm in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: click in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.11.6)
# Requirement already satisfied: joblib in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: filetype>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: promptflow-tracing==1.16.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (4.23.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.18.6)
# Requirement already satisfied: docstring_parser in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.115.6)
# Requirement already satisfied: psutil in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (5.9.8)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.29.0)
# Requirement already satisfied: openai in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.57.2)
# Requirement already satisfied: tiktoken>=0.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.8.0)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.16.1)
# Requirement already satisfied: pywin32 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (308)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (10.4.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.36)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.7.3)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.0b32)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (24.3.1)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.29.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.1)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (7.0.7)
# Requirement already satisfied: httpx>=0.25.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: argcomplete>=3.2.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.5.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.4.6)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.1.43)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.23.1)
# Requirement already satisfied: msrest>=0.6.10 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: fixedint==0.1.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.29.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.10.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: blinker>=1.9 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.4)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (9.0.1)
# Requirement already satisfied: pytz in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.2)
# Requirement already satisfied: importlib-resources in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (6.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.0.11)
# Requirement already satisfied: idna in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.10)
# Requirement already satisfied: certifi in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.14.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2024.10.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.22.3)
# Requirement already satisfied: importlib-metadata>=4.11.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (8.5.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.2.3)
# Requirement already satisfied: jaraco.classes in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.15.0->azure-ai-evaluation) (24.2)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msal-extensions>=1.2.0->azure-identity>=1.16.0->azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.29.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.66.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.29.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core>=1.15.0->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.1.1)
# Requirement already satisfied: pycparser in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.50b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.27.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.2.2)
# Requirement already satisfied: more-itertools in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (10.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.8.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: promptflow-azure in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (1.16.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (2.10.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (1.32.0)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (1.22.4)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.16.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (1.16.2)
# Requirement already satisfied: azure-storage-blob[aio]<13.0.0,>=12.17.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (12.24.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (4.9.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-azure) (1.19.0)
# Requirement already satisfied: colorama in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: strictyaml in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: typing-extensions in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.12.2)
# Requirement already satisfied: isodate in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-storage-file-share in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.20.0)
# Requirement already satisfied: tqdm in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.67.1)
# Requirement already satisfied: opencensus-ext-azure in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.13)
# Requirement already satisfied: msrest>=0.6.18 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.1)
# Requirement already satisfied: pydash>=6.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: jsonschema>=4.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.23.0)
# Requirement already satisfied: marshmallow>=3.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.23.1)
# Requirement already satisfied: opencensus-ext-logging in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.1)
# Requirement already satisfied: pyyaml>=5.1.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.18.0)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.5.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.31.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (44.0.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.2.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.0.36)
# Requirement already satisfied: httpx>=0.25.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.28.1)
# Requirement already satisfied: argcomplete>=3.2.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.5.2)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (10.4.0)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.16.1)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.0.2)
# Requirement already satisfied: pywin32 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (308)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.43)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.0.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.16.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.16.2)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.9.0)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (24.3.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.3.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.2.3)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.0b32)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.29.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.1)
# Requirement already satisfied: aiohttp>=3.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.11.10)
# Requirement already satisfied: fixedint==0.1.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk~=1.26 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.29.0)
# Requirement already satisfied: psutil~=5.9 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.9.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: Flask>=0.9 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.0)
# Requirement already satisfied: pytz in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.2)
# Requirement already satisfied: importlib-resources in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (6.4.5)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (9.0.1)
# Requirement already satisfied: werkzeug!=2.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (4.0.11)
# Requirement already satisfied: httpcore==1.* in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.7)
# Requirement already satisfied: certifi in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.8.30)
# Requirement already satisfied: idna in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.10)
# Requirement already satisfied: anyio in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (4.7.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.22.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.35.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.2.3)
# Requirement already satisfied: importlib-metadata>=4.11.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (8.5.0)
# Requirement already satisfied: jaraco.classes in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.4.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from marshmallow>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.2)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.10.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.2.15)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.29.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.66.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.29.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.2.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.2)
# Requirement already satisfied: docstring_parser in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.16)
# Requirement already satisfied: promptflow-tracing==1.16.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.16.2)
# Requirement already satisfied: filetype>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.2.0)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.115.6)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.18.6)
# Requirement already satisfied: openai in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.57.2)
# Requirement already satisfied: tiktoken>=0.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.1)
# Requirement already satisfied: opencensus<1.0.0,>=0.11.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.11.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (0.2.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (1.18.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from aiohttp>=3.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.4.4)
# Requirement already satisfied: pycparser in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.17.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.10.3)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.41.3)
# Requirement already satisfied: blinker>=1.9 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (8.1.7)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.21.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.24.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from opentelemetry-sdk~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.50b0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from werkzeug!=2.0.0->flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.2.2)
# Requirement already satisfied: more-itertools in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (10.5.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.37.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.11.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.8.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (5.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: azure-identity in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (1.19.0)
# Requirement already satisfied: msal>=1.30.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity) (44.0.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity) (4.12.2)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-identity) (1.32.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (308)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sumohammed\development\aoai_model_evaluation_benchmarks\aoai_eval\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Parameters and imports

# %% [markdown]
# Here we define the data, `grounding.json` on which we will simulate query and response pairs to help us evaluate the groundedness of our model's responses. Based on the use case of your model, the data you use to evaluate groundedness might differ.

# %%
import os
from typing import Any, Dict, List, Optional
import json
from pathlib import Path

from azure.ai.evaluation import evaluate
from azure.ai.evaluation import GroundednessEvaluator,GroundednessProEvaluator
from azure.ai.evaluation.simulator import Simulator
from openai import AzureOpenAI
import importlib.resources as pkg_resources
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# %%
import os
from dotenv import load_dotenv
load_dotenv("../.credentials.env")
# Out:
# True

# %%
azure_ai_project = {
    "subscription_id": os.environ.get("AZURE_SUBSCRIPTION_ID"),
    "resource_group_name": os.environ.get("AZURE_RESOURCE_GROUP"),
    "project_name": os.environ.get("AZURE_PROJECT_NAME"),
}

model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": os.environ.get("AZURE_OPENAI_API_KEY"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT"),
    "api_version": os.environ.get("AZURE_OPENAI_API_VERSION"),
}

# %%
print(azure_ai_project)
print(model_config)
# Out:
# {'subscription_id': '687537c9-1139-4975-85ff-c4822c224772', 'resource_group_name': 'rg-sumohammed-6118_ai', 'project_name': 'sumohammed-0192'}
# {'azure_endpoint': 'https://ai-testenv387254641388.services.ai.azure.com/', 'api_key': 'AsCgtEOpwATRAQVbQlgJfgpN990xCTp4T7EJCgkyavnvxOU6EhNbJQQJ99AKACmepeSXJ3w3AAAAACOGv9H3', 'azure_deployment': 'gpt-4o', 'api_version': '2024-08-01-preview'}

# %% [markdown]
# ## Data
# Here we define the data, `grounding.json` on which we will simulate query and response pairs to help us evaluate the groundedness of our model's responses. Based on the use case of your model, the data you use to evaluate groundedness might differ.

# %%
resource_name = "grounding.json"
package = "azure.ai.evaluation.simulator._data_sources"
conversation_turns = []

with pkg_resources.path(package, resource_name) as grounding_file, Path.open(grounding_file, "r") as file:
    data = json.load(file)

for item in data:
    conversation_turns.append([item])
    if len(conversation_turns) == 2:
        break

# %% [markdown]
# ## Target Endpoint
#
# We will use Evaluate API provided by Azure AI Evaluations SDK. It requires a target Application or python Function, which handles a call to LLMs and retrieve responses.

# %%
def example_application_response(query: str, context: str) -> str:
    deployment = os.environ.get("AZURE_OPENAI_DEPLOYMENT")
    endpoint = os.environ.get("AZURE_OPENAI_ENDPOINT")
    token_provider = get_bearer_token_provider(DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

    # Get a client handle for the AOAI model
    client = AzureOpenAI(
        azure_endpoint=endpoint,
        api_version=os.environ.get("AZURE_OPENAI_API_VERSION"),
        azure_ad_token_provider=token_provider,
    )

    # Prepare the messages
    messages = [
        {
            "role": "system",
            "content": f"You are a user assistant who helps answer questions based on some context.\n\nContext: '{context}'",
        },
        {"role": "user", "content": query},
    ]
    # Call the model
    completion = client.chat.completions.create(
        model=deployment,
        messages=messages,
        max_tokens=800,
        temperature=0.7,
        top_p=0.95,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None,
        stream=False,
    )

    message = completion.to_dict()["choices"][0]["message"]
    if isinstance(message, dict):
        message = message["content"]
    return message

# %% [markdown]
# ## Run the simulator
#
# The interactions between your endpoint (in this case, `example_application_response`) and the simulator is managed by a callback method, `custom_simulator_callback` and this method is used to format the request to your endpoint and the response from the endpoint.

# %%
async def custom_simulator_callback(
    messages: List[Dict],
    stream: bool = False,
    session_state: Optional[str] = None,
    context: Optional[Dict[str, Any]] = None,
) -> dict:
    messages_list = messages["messages"]
    # get last message
    latest_message = messages_list[-1]
    application_input = latest_message["content"]
    context = latest_message.get("context", None)
    # call your endpoint or ai application here
    response = example_application_response(query=application_input, context=context)
    # we are formatting the response to follow the openAI chat protocol format
    message = {
        "content": response,
        "role": "assistant",
        "context": context,
    }
    messages["messages"].append(message)
    return {"messages": messages["messages"], "stream": stream, "session_state": session_state, "context": context}

# %%
custom_simulator = Simulator(model_config=model_config)
# Out:
# Class Simulator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
outputs = await custom_simulator(
    target=custom_simulator_callback,
    conversation_turns=conversation_turns,
    max_conversation_turns=1,
    concurrent_async_tasks=10,
)
# Out:
# Simulating with predefined conversation turns: 100%|████████████| 2/2 [00:14<00:00,  7.23s/messages]

# %% [markdown]
# ### Convert the outputs to a format that can be evaluated

# %%
output_file = "ground_sim_output.jsonl"
with open(output_file, "w") as file:
    for output in outputs:
        file.write(output.to_eval_qr_json_lines())

# %% [markdown]
# ## Run the evaluation
#
# In this section, we will run the evaluation using the `GroundednessEvaluator` and the `evaluate` function from the Azure AI Evaluation SDK. The evaluation will assess the groundedness of the model's responses based on the dataset produced by the `Simulator` above.

# %%
from azure.identity import DefaultAzureCredential
credential = DefaultAzureCredential()

groundedness_evaluator = GroundednessEvaluator(model_config=model_config)
groundedness_pro_evaluator = GroundednessProEvaluator(azure_ai_project=azure_ai_project, credential=credential)

eval_output = evaluate(
    data=output_file,
    evaluators={
        "groundedness": groundedness_evaluator,
        "groundedness_pro": groundedness_pro_evaluator,

    },
    azure_ai_project=azure_ai_project,
)

print(eval_output)
# Out:
# Class GroundednessProEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# [2024-12-13 11:50:33 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-12-13 11:50:34 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-12-13 11:50:34 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557, log path: C:\Users\sumohammed\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557\logs.txt
# [2024-12-13 11:50:34 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557, log path: C:\Users\sumohammed\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557\logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557
# 2024-12-13 11:50:34 +0000   23736 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-12-13 11:50:38 +0000   23736 execution.bulk     INFO     Finished 1 / 2 lines.
# 2024-12-13 11:50:38 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 4.58 seconds. Estimated time for incomplete lines: 4.58 seconds.
# 2024-12-13 11:50:41 +0000   23736 execution.bulk     INFO     Finished 2 / 2 lines.
# 2024-12-13 11:50:41 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 3.68 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557"
# Run status: "Completed"
# Start time: "2024-12-13 11:50:32.751557+00:00"
# Duration: "0:00:09.602850"
# Output path: "C:\Users\sumohammed\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557"
#
# 2024-12-13 11:50:49 +0000   23736 execution.bulk     INFO     Finished 1 / 2 lines.
# 2024-12-13 11:50:49 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 15.57 seconds. Estimated time for incomplete lines: 15.57 seconds.
# 2024-12-13 11:50:58 +0000   23736 execution.bulk     INFO     Finished 2 / 2 lines.
# 2024-12-13 11:50:58 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 12.1 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-12-13 11:50:34 +0000   23736 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-12-13 11:50:49 +0000   23736 execution.bulk     INFO     Finished 1 / 2 lines.
# 2024-12-13 11:50:49 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 15.57 seconds. Estimated time for incomplete lines: 15.57 seconds.
# 2024-12-13 11:50:58 +0000   23736 execution.bulk     INFO     Finished 2 / 2 lines.
# 2024-12-13 11:50:58 +0000   23736 execution.bulk     INFO     Average execution time for completed lines: 12.1 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557"
# Run status: "Completed"
# Start time: "2024-12-13 11:50:32.751557+00:00"
# Duration: "0:00:26.355146"
# Output path: "C:\Users\sumohammed\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:09.602850",
#         "completed_lines": 2,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\sumohammed\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_klz43hfn_20241213_115032_751557"
#     },
#     "groundedness_pro": {
#         "status": "Completed",
#         "duration": "0:00:26.355146",
#         "completed_lines": 2,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\sumohammed\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j3jo5lmu_20241213_115032_751557"
#     }
# }
#
# ====================================================
#
# {'rows': [{'inputs.query': 'What is the process to convert microliters to liters using the given conversion factor?', 'inputs.response': "To convert microliters (µL) to liters (L), you can use the conversion factor provided: \n\n1 microliter (µL) is equal to 1.0E-6 liters (L).\n\nTo perform the conversion, you multiply the number of microliters by the conversion factor. Here's the step-by-step process:\n\n1. Determine the quantity in microliters that you want to convert.\n2. Multiply that quantity by 1.0E-6 to get the equivalent value in liters.\n\nFor example, if you want to convert 15 microliters to liters:\n\n15 µL × 1.0E-6 L/µL = 1.5E-5 L\n\nTherefore, 15 microliters is equal to 1.5E-5 liters.", 'inputs.context': '```json\n{"web_search_results":[{"index":"1","title":"9/10 liters to litres - CoolConversion","snippet":"To calculate a liter value to the corresponding value in litre, just multiply the quantity in liter by 1 (the conversion factor). Here is the formula: Value in litres = value in liter × 1 Suppose you want to convert 0.9 liter into litres. Using the conversion formula above, you will get: Value in litre = 0.9 × 1 = 0.9 litres","url":"https://coolconversion.com/volume/9/10-liter-to-litre"},{"index":"2","title":"Convert l to ml","snippet":"Liter to Milliliter Conversion Table How to Convert Liter to Milliliter 1 L, l = 1000 mL 1 mL = 0.001 L, l Example: convert 15 L, l to mL: 15 L, l = 15 × 1000 mL = 15000 mL Popular Volume Unit Conversions liters to gallons gallons to liters ml to cups cups to ml tablespoons to cups cups to tablespoons ml to l l to ml teaspoon to ml ml to teaspoon","url":"https://www.unitconverters.net/volume/l-to-ml.htm"},{"index":"3","title":"Convert Microliter to Liter","snippet":"Please provide values below to convert microliter [µL] to liter [L, l], or vice versa. Microliter to Liter Conversion Table How to Convert Microliter to Liter 1 µL = 1.0E-6 L, l 1 L, l = 1000000 µL Example: convert 15 µL to L, l: 15 µL = 15 × 1.0E-6 L, l = 1.5E-5 L, l Popular Volume Unit Conversions liters to gallons gallons to liters ml to cups","url":"https://www.unitconverters.net/volume/microliter-to-liter.htm"}]}\n```\n```json\n{"web_search_results":[{"index":"4","title":"How To Convert 10^3/uL To 10^9/L? - Blurtit","snippet":"How To Convert 10^3/uL To 10^9/L? 2 Answers Fangju Fangju answered 1 μl = 0.000 001 liters, so 10 3 ul = 10 9 liters. Thank Writer Blurt Kevin Cronk answered Ummm...that IS the conversion...micro litres to litres - add 6 decimal places Thank Writer You might also like... How To Convert Celsius To Fahrenheit? Climate","url":"https://education.blurtit.com/2891089/how-to-convert-103ul-to-109l"},{"index":"5","title":"How I diagnose and treat neutropenia - PubMed","snippet":"Purpose of review: Neutropenia absolute neutrophil count (ANC) less than 1.5 × 10 (9)/l is a common hematological finding, and severe neutropenia, that is, ANC less than 0.5 × 10 (9)/l is a well known risk factor for susceptibility to bacterial infections. This review provides a succinct clinical approach to the diagnosis and treatment of neutropenia with specific recommendations on the treatment of severe chronic neutropenia with the myeloid growth factor, granulocyte colony-stimulating ...","url":"https://pubmed.ncbi.nlm.nih.gov/26554885/"},{"index":"6","title":"血小板计数为500×10^9/L严重吗_有来医生","snippet":"血常规中血小板计数的正常值，通常在100-300x10^9/L之间，血小板计数400x10^9/L是异常增高。 引起血小板增多的原因，包括原发性血小板增多症。 这是血液系统疾病，是由于单克隆细胞增殖异常引起的。 还有反应性的血小板增多，例如严重的炎症、恶性肿瘤、严重失血或溶血性贫血、缺铁性贫血等患者，都会出现反应性血小板计数增加。 血小板计数400x10^9/L并不一定代表癌症，要进一步检查明确引起血小板增多的原因，才能知道是否为癌症导致的。 血小板计数增多的患者，可能出现的临床表现有全身疲乏、乏力、脾脏增大或出血风险增加。 语音时长 01:18\'\' 聂志扬 │北京医院 2019/08/01 收听 (78214) 血小板500多严重吗","url":"https://www.youlai.cn/video/article/58C0EE8kaO.html"}]}\n```\n```json\n{"web_search_results":[{"index":"7","title":"How To Convert 10^3/uL To 10^9/L? - Blurtit","snippet":"How To Convert 10^3/uL To 10^9/L? 2 Answers Fangju Fangju answered 1 μl = 0.000 001 liters, so 10 3 ul = 10 9 liters. Thank Writer ...

# %%
from pprint import pprint 
pprint(eval_output)
# Out:
# {'metrics': {'groundedness.gpt_groundedness': 5.0,
#              'groundedness.groundedness': 5.0,
#              'groundedness_pro.groundedness_pro_passing_rate': 1.0},
#  'rows': [{'inputs.context': '```json\n'
#                              '{"web_search_results":[{"index":"1","title":"9/10 '
#                              'liters to litres - CoolConversion","snippet":"To '
#                              'calculate a liter value to the corresponding '
#                              'value in litre, just multiply the quantity in '
#                              'liter by 1 (the conversion factor). Here is the '
#                              'formula: Value in litres = value in liter × 1 '
#                              'Suppose you want to convert 0.9 liter into '
#                              'litres. Using the conversion formula above, you '
#                              'will get: Value in litre = 0.9 × 1 = 0.9 '
#                              'litres","url":"https://coolconversion.com/volume/9/10-liter-to-litre"},{"index":"2","title":"Convert '
#                              'l to ml","snippet":"Liter to Milliliter '
#                              'Conversion Table How to Convert Liter to '
#                              'Milliliter 1 L, l = 1000 mL 1 mL = 0.001 L, l '
#                              'Example: convert 15 L, l to mL: 15 L, l = 15 × '
#                              '1000 mL = 15000 mL Popular Volume Unit '
#                              'Conversions liters to gallons gallons to liters '
#                              'ml to cups cups to ml tablespoons to cups cups '
#                              'to tablespoons ml to l l to ml teaspoon to ml ml '
#                              'to '
#                              'teaspoon","url":"https://www.unitconverters.net/volume/l-to-ml.htm"},{"index":"3","title":"Convert '
#                              'Microliter to Liter","snippet":"Please provide '
#                              'values below to convert microliter [µL] to liter '
#                              '[L, l], or vice versa. Microliter to Liter '
#                              'Conversion Table How to Convert Microliter to '
#                              'Liter 1 µL = 1.0E-6 L, l 1 L, l = 1000000 µL '
#                              'Example: convert 15 µL to L, l: 15 µL = 15 × '
#                              '1.0E-6 L, l = 1.5E-5 L, l Popular Volume Unit '
#                              'Conversions liters to gallons gallons to liters '
#                              'ml to '
#                              'cups","url":"https://www.unitconverters.net/volume/microliter-to-liter.htm"}]}\n'
#                              '```\n'
#                              '```json\n'
#                              '{"web_search_results":[{"index":"4","title":"How '
#                              'To Convert 10^3/uL To 10^9/L? - '
#                              'Blurtit","snippet":"How To Convert 10^3/uL To '
#                              '10^9/L? 2 Answers Fangju Fangju answered 1 μl = '
#                              '0.000 001 liters, so 10 3 ul = 10 9 liters. '
#                              'Thank Writer Blurt Kevin Cronk answered '
#                              'Ummm...that IS the conversion...micro litres to '
#                              'litres - add 6 decimal places Thank Writer You '
#                              'might also like... How To Convert Celsius To '
#                              'Fahrenheit? '
#                              'Climate","url":"https://education.blurtit.com/2891089/how-to-convert-103ul-to-109l"},{"index":"5","title":"How '
#                              'I diagnose and treat neutropenia - '
#                              'PubMed","snippet":"Purpose of review: '
#                              'Neutropenia absolute neutrophil count (ANC) less '
#                              'than 1.5 × 10 (9)/l is a common hematological '
#                              'finding, and severe neutropenia, that is, ANC '
#                              'less than 0.5 × 10 (9)/l is a well known risk '
#                              'factor for susceptibility to bacterial '
#                              'infections. This review provides a succinct '
#                              'clinical approach to the diagnosis and treatment '
#                              'of neutropenia with specific recommendations on '
#                              'the treatment of severe chronic neutropenia with '
#                              'the myeloid growth factor, granulocyte '
#                              'colony-stimulating '
#                              '...","url":"https://pubmed.ncbi.nlm.nih.gov/26554885/"},{"index":"6","title":"血小板计数为500×10^9/L严重吗_有来医生","snippet":"血常规中血小板计数的正常值，通常在100-300x10^9/L之间，血小板计数400x10^9/L是异常增高。 '
#                              '引起血小板增多的原因，包括原发性血小板增多症。 '
#                              '这是血液系统疾病，是由于单克隆细胞增殖异常引起的。 '
#                              '还有反应性的血小板增多，例如严重的炎症、恶性肿瘤、严重失血或溶血性贫血、缺铁性贫血等患者，都会出现反应性血小板计数增加。 '
#                              '血小板计数400x10^9/L并不一定代表癌症，要进一步检查明确引起血小板增多的原因，才能知道是否为癌症导致的。 '
#                              '血小板计数增多的患者，可能出现的临床表现有全身疲乏、乏力、脾脏增大或出血风险增加。 语音时长 '
#                              "01:18'' 聂志扬 │北京医院 2019/08/01 收听 (78214) "
#                              '血小板500多严重吗","url":"https://www.youlai.cn/video/article/58C0EE8kaO.html"}]}\n'
#                              '```\n'
#                              '```json\n'
#                              '{"web_search_results":[{"index":"7","title":"How '
#                              'To Convert 10^3/uL To 10^9/L? - '
#                              'Blurtit","snippet":"How To Convert 10^3/uL To '
#                              '10^9/L? 2 Answers Fangju Fangju answered 1 μl = '
#                              '0.000 001 liters, so 10 3 ul = 10 9 liters. '
#                              'Thank Writer Blurt Kevin Cronk answered '
#                              'Ummm...that IS the conversion...micro litres to '
#                              'litres - add 6 decimal places Thank Writer You '
#                              'might also like... How To Convert Celsius To '
#                              'Fahrenheit? '
#                              'Climate","url":"https://education.blurtit.com/2891089/how-to-convert-103ul-to-109l"},{"index":"8","title":"WBC '
#                              'counts and units | Pathology '
#                              'Student","snippet":"It would be correct to say '
#                              'that 60,000/mm 3 Â is a high white count. This '
#                              'number would be equivalent to 60.0 x 10 9 /L in '
#                              'the SI system. Â The other number you listed – '
#                              '6.0 x 10 9 /LÂ – is within the normal range. And '
#                              'you’re right: 60,000 xÂ 10 9 /L would be a '
#                              'ridiculously high white count (one that would '
#                              'not be seen in '
#                              'humans!).","url":"https://www.pathologystudent.com/8423/"},{"index":"9","title":"Definitions '
#                              'of the SI units: The twenty SI prefixes - '
#                              'NIST","snippet":"Because the SI prefixes '
#                              'strictly represent powers of 10, they should not '
#                              'be used to represent powers of 2. Thus, one '
#                              'kilobit, or 1 kbit, is 1000 bit and not 2 10 bit '
#                              '= 1024 bit. To alleviate this ambiguity, '
#                              'prefixes for binary multiples have been adopted '
#                              'by the International Electrotechnical Commission '
#                              '(IEC) for use in information '
#                              'technology.","url":"https://physics.nist.gov/cuu/Units/prefixes.html"}]}\n'
#                              '```',
#            'inputs.query': 'What is the process to convert microliters to '
#                            'liters using the given conversion factor?',
#            'inputs.response': 'To convert microliters (µL) to liters (L), you '
#                               'can use the conversion factor provided: \n'
#                               '\n'
#                               '1 microliter (µL) is equal to 1.0E-6 liters '
#                               '(L).\n'
#                               '\n'
#                               'To perform the conversion, you multiply the '
#                               'number of microliters by the conversion factor. '
#                               "Here's the step-by-step process:\n"
#                               '\n'
#                               '1. Determine the quantity in microliters that '
#                               'you want to convert.\n'
#                               '2. Multiply that quantity by 1.0E-6 to get the '
#                               'equivalent value in liters.\n'
#                               '\n'
#                               'For example, if you want to convert 15 '
#                               'microliters to liters:\n'
#                               '\n'
#                               '15 µL × 1.0E-6 L/µL = 1.5E-5 L\n'
#                               '\n'
#                               'Therefore, 15 microliters is equal to 1.5E-5 '
#                               'liters.',
#            'line_number': 0,
#            'outputs.groundedness.gpt_groundedness': 5,
#            'outputs.groundedness.groundedness': 5,
#            'outputs.groundedness.groundedness_reason': 'The RESPONSE '
#                                                        'accurately reflects '
#                                                        'the information '
#                                                        'provided in the '
#                                                        'CONTEXT without adding '
#                                                        'unsupported details or '
#                                                        'omitting critical '
#                                                        'information. It is a '
#                                                        'complete and faithful '
#                                                        'representation of the '
#                                                        'data given.',
#            'outputs.groundedness_pro.groundedness_pro_label': True,
#            'outputs.groundedness_pro.groundedness_pro_reason': 'All Contents '
#                                                                'are grounded'},
#           {'inputs.context': '```json\n'
#                              '{"web_search_results":[{"index":"1","title":"FARMER '
#                              '& FRENCHMAN - 190 Photos & 69 Reviews - '
#                              'Yelp","snippet":"This quaint little winery just '
#                              'south of Henderson, KY is easy to find and has a '
#                              'ton of potential. The atmosphere is beautiful, '
#                              'however, the hosting and staff made the '
#                              'experience awkward and not as enjoyable. You '
#                              'drive up to a gorgeous venue but are quickly '
#                              'greeted by staff members smoking '
#                              'outside.","url":"https://www.yelp.com/biz/farmer-and-frenchman-robards-2"},{"index":"2","title":"Farmer '
#                              'and Frenchman Winery (Henderson) - '
#                              'Tripadvisor","snippet":"Farmer and Frenchman '
#                              'Winery 4.5 The area Reviews 73 #3 of 19 things '
#                              'to do in Henderson Wineries & Vineyards Visit '
#                              'website Call Email Write a review What people '
#                              'are saying By TourWorld “ Rustic Elegance ” Jul '
#                              '2022 We also ordered breakfast which was a '
#                              'delicious frittata, cheese, garlic knots and '
#                              'honey. “ Farmer and Frenchman ” Aug '
#                              '2019","url":"https://www.tripadvisor.com/Attraction_Review-g39500-d10727654-Reviews-Farmer_and_Frenchman_Winery-Henderson_Kentucky.html"},{"index":"3","title":"Farmer '
#                              '& Frenchman - Henderson, KY - '
#                              'Yelp","snippet":"FARMER & FRENCHMAN - 182 Photos '
#                              '& 68 Reviews - Wineries - 12522 Hwy 41 S, '
#                              'Henderson, KY - Restaurant Reviews - Phone '
#                              'Number - Yelp Farmer & Frenchman 68 reviews '
#                              'Claimed $$ Wineries, Venues & Event Spaces, '
#                              'Cafes See 182 photos Kite & Key Cafe on Franklin '
#                              'Frequently Asked Questions about Farmer & '
#                              'Frenchman Does Farmer & Frenchman take '
#                              'reservations?","url":"https://www.yelp.com/biz/farmer-and-frenchman-henderson-2?start=20"}]}\n'
#                              '```\n'
#                              '```json\n'
#                              '{"web_search_results":[{"index":"4","title":"Home '
#                              '- Farmer and Frenchman Winery","snippet":"Farmer '
#                              'and Frenchman is a Kentucky small-farm vineyard, '
#                              'winery, cafe, and event venue – a distinctive '
#                              'agricultural destination located in Henderson '
#                              'County. Guests to F&F can expect a unique blend '
#                              'of wine tasting, local food and entertainment '
#                              'experiences rooted in the past but with a fresh '
#                              'and stylish '
#                              'twist.","url":"https://farmerandfrenchman.com/"},{"index":"5","title":"Farmer '
#                              'and Frenchman Cabins - Farmer and Frenchman '
#                              'Winery","snippet":"On a vineyard in Western '
#                              'Kentucky sits private guest cabins that overlook '
#                              'gorgeous farmlands. Farmer and Frenchman Winery '
#                              'and Cafe sits within walking distance of all '
#                              'three cabins and guests are able to enjoy quiet '
#                              'escape that the cabins provide. These popular '
#                              'overnight cabins have been voted as one of the '
#                              'Best Long Weekend Getaways in '
#                              'Kentucky.","url":"https://farmerandfrenchman.com/farmer-and-frenchman-cabins/"},{"index":"6","title":"Online '
#                              'Menu of Farmer & Frenchman Restaurant, '
#                              'Henderson, Kentucky ...","snippet":"Farmer & '
#                              'Frenchman « Back To Henderson, KY 7.46 mi Cafes '
#                              '$$ (270) 748-1856 12522 Hwy 41 S, Henderson, KY '
#                              '42420 Hours Mon Closed Tue 12:00pm-9:00pm Wed '
#                              '12:00pm-9:00pm Thu 12:00pm-9:00pm Fri '
#                              '12:00pm-9:00pm Sat 12:00pm-9:00pm Sun Closed '
#                              'Claim This Business Is this your business? Claim '
#                              'now to immediately update business information '
#                              'and '
#                              'menu!","url":"https://www.zmenu.com/farmer-and-frenchman-henderson-online-menu/"}]}\n'
#                              '```',
#            'inputs.query': 'What unique experiences does Farmer and Frenchman '
#                            'offer to its visitors?',
#            'inputs.response': 'Farmer and Frenchman offers a variety of unique '
#                               'experiences to its visitors. It is a small-farm '
#                               'vineyard, winery, cafe, and event venue located '
#                               'in Henderson County, Kentucky. Visitors can '
#                               'enjoy wine tasting, local food, and '
#                               'entertainment experiences that combine a rustic '
#                               'past with a fresh and stylish twist. The winery '
#                               'also features private guest cabins overlooking '
#                               'farmlands, providing a quiet escape. These '
#                               'cabins have been recognized as one of the Best '
#                               'Long Weekend Getaways in Kentucky. '
#                               'Additionally, guests can enjoy the beautiful '
#                               'atmosphere of the venue, although some reviews '
#                               'have noted that the hosting and staff could '
#                               'impact the experience.',
#            'line_number': 1,
#            'outputs.groundedness.gpt_groundedness': 5,
#            'outputs.groundedness.groundedness': 5,
#            'outputs.groundedness.groundedness_reason': 'The RESPONSE '
#                                                        'accurately and '
#                                                        'thoroughly conveys all '
#                                                        'essential information '
#                                                        'from the CONTEXT '
#                                                        'without introducing '
#                                                        'unsupported details or '
#                                                        'omitting critical '
#                                                        'points.',
#            'outputs.groundedness_pro.groundedness_pro_label': True,
#            'outputs.groundedness_pro.groundedness_pro_reason': 'All Contents '
#                                                                'are grounded'}],
#  'studio_url': 'https://ai.azure.com/build/evaluation/317dfc74-1327-479b-b764-b025e23b0c6d?wsid=/subscriptions/687537c9-1139-4975-85ff-c4822c224772/resourceGroups/rg-sumohammed-6118_ai/providers/Microsoft.MachineLearningServices/workspaces/sumohammed-0192'}
